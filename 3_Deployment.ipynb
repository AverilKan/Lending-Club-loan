# %% [markdown]
#  # Notebook 3 — Deployment & Inference
#
#  This notebook demonstrates end-to-end inference using the trained model from Notebook 2. It loads the saved artifact (pipeline, threshold, and metadata) and generates default probability predictions on new loan applications using the F2-optimized decision threshold from the validation stage.

# %%
import sys
from pathlib import Path

import joblib
import numpy as np
import pandas as pd

# %% [markdown]
#  ## 0. Locate Project Root
#
#  The project root is located dynamically to support execution from any directory.

# %%
def find_project_root(start: Path | None = None) -> Path:
    """Locate project root by searching upwards for src/ and data/ directories."""
    start = (start or Path.cwd()).resolve()

    # Walk upwards until we find a folder that looks like the repo root.
    for p in [start, *start.parents]:
        if (p / "src").is_dir() and (p / "data").is_dir():
            return p

    raise RuntimeError(
        "Can't locate project root. Expected to find 'src/' and 'data/' in the same directory. "
        f"Started search from: {start}"
    )


PROJECT_ROOT = find_project_root()
MODELS_DIR = PROJECT_ROOT / "models"
DATA_DIR = PROJECT_ROOT / "data"

sys.path.insert(0, str(PROJECT_ROOT))

print(f"PROJECT_ROOT: {PROJECT_ROOT}")
print(f"MODELS_DIR:    {MODELS_DIR}")
print(f"DATA_DIR:      {DATA_DIR}")
# Out:
# PROJECT_ROOT: /Users/avka/Documents/code/Lending-Club-loan
# MODELS_DIR:    /Users/avka/Documents/code/Lending-Club-loan/models
# DATA_DIR:      /Users/avka/Documents/code/Lending-Club-loan/data

# %% [markdown]
#  ## 1. Load the saved model artifact

# %%
artifact_path = MODELS_DIR / "credit_risk_pipeline_investor.joblib"
if not artifact_path.exists():
    raise FileNotFoundError(
        f"Artifact not found at: {artifact_path}\n"
        "Run Notebook 2 end-to-end to generate the saved artifact first."
    )

artifact = joblib.load(artifact_path)

required_keys = ["pipeline", "threshold", "model_name", "test_auc", "metadata"]
missing = [k for k in required_keys if k not in artifact]
if missing:
    raise KeyError(f"Artifact missing required keys: {missing}. Found keys: {sorted(artifact.keys())}")

pipeline = artifact["pipeline"]
threshold = float(artifact["threshold"])
metadata = artifact["metadata"]

print("=" * 90)
print("MODEL ARTIFACT LOADED")
print("=" * 90)
print(f"Model name:              {artifact['model_name']}")
print(f"Packaged model Test AUC: {artifact['test_auc']:.4f}  (computed from packaged TRAIN+VAL model)")
if "selection_test_auc" in artifact:
    print(f"Selection Test AUC:      {artifact['selection_test_auc']:.4f}  (from TRAIN-only evaluation stage)")
print(f"Decision threshold:      {threshold:.4f}  ({metadata.get('threshold_policy', 'N/A')})")
print(f"Training period:         {metadata.get('train_period', 'N/A')}")
print(f"Training samples (packaged): {metadata.get('packaged_train_samples', 'N/A'):,}  (TRAIN+VAL)")
if 'selection_train_samples' in metadata:
    print(f"Training samples (selection): {metadata.get('selection_train_samples', 'N/A'):,}  (TRAIN only)")
print(f"Validation samples:      {metadata.get('val_samples', 'N/A'):,}")
print(f"Test samples:            {metadata.get('test_samples', 'N/A'):,}")
print(f"Created:                 {metadata.get('created_date', 'N/A')}")
print("=" * 90)
# Out:
# ...
# MODEL ARTIFACT LOADED
# ...
# Model name:              Default LogReg Investor
# Packaged model Test AUC: 0.6866  (computed from packaged TRAIN+VAL model)
# Selection Test AUC:      0.6769  (from TRAIN-only evaluation stage)
# Decision threshold:      0.3794  (Max F2 on Val(2014) using TRAIN-only model)
# Training period:         2011-2013
# Training samples (packaged): 338,080  (TRAIN+VAL)
# Training samples (selection): 175,510  (TRAIN only)
# Validation samples:      162,570
# Test samples:            283,026
# Created:                 2026-01-05 15:03:28
# ...

# %% [markdown]
#  ## 2. Load sample applications
#
#  `data/sample_applications.csv` should contain raw application rows (same schema used in Notebook 2).

# %%
# Try a few common candidate names for convenience
sample_candidates = [
    DATA_DIR / "sample_applications.csv",
    DATA_DIR / "sample_application.csv",
    DATA_DIR / "sample_loans.csv",
]
sample_path = next((p for p in sample_candidates if p.exists()), None)
if sample_path is None:
    raise FileNotFoundError(
        "Could not find sample applications file. Looked for:\n"
        + "\n".join([str(p) for p in sample_candidates])
    )

df_sample = pd.read_csv(sample_path)

print(f"\nLoaded sample applications: {sample_path.name}")
print(f"Rows: {len(df_sample):,} | Cols: {df_sample.shape[1]:,}")

# Preview a few "human readable" fields if present
preview_cols = [c for c in ["loan_amnt", "term", "int_rate", "emp_length", "annual_inc",
                            "fico_range_low", "dti", "purpose"] if c in df_sample.columns]
if preview_cols:
    print("\nPreview:")
    print(df_sample[preview_cols].head(7).to_string(index=False))
# Out:
# Loaded sample applications: sample_applications.csv
# Rows: 6 | Cols: 151
#
# Preview:
#  loan_amnt       term  int_rate emp_length  annual_inc  fico_range_low   dti            purpose
#       3600  36 months     13.99  10+ years       55000             675  5.91 debt_consolidation
#      24700  36 months     11.99  10+ years       65000             715 16.06     small_business
#      20000  60 months     10.78  10+ years       63000             695 10.78   home_improvement
#      22400  60 months     12.88    6 years       95000             710 22.98 debt_consolidation
#      16000  60 months     12.88     1 year       70000             720 26.40 debt_consolidation
#       1400  36 months     12.88    3 years       64000             700 34.95              other

# %% [markdown]
#  ## 3. Run predictions (probabilities + decisions)

# %%
try:
    proba = pipeline.predict_proba(df_sample)[:, 1]
except Exception as e:
    # Don't hide the error; make it actionable.
    raise RuntimeError(
        "Pipeline failed during predict_proba on sample applications.\n"
        "This usually means one of:\n"
        "  - src/transformers.py not importable (sys.path not set)\n"
        "  - Schema mismatch (required raw columns missing)\n"
        "  - Inference-time parsing issues (unexpected string formats)\n"
        f"\nOriginal error: {type(e).__name__}: {e}"
    ) from e

pred = (proba >= threshold).astype(int)

results = df_sample.copy()
results.insert(0, "row_id", np.arange(len(results)))
results["default_probability"] = proba
results["predicted_default"] = pred
results["decision"] = np.where(results["predicted_default"] == 1, "REJECT", "APPROVE")

# Keep the output readable in terminal
show_cols = ["row_id", "default_probability", "predicted_default", "decision"]
for c in ["loan_amnt", "term", "int_rate", "fico_range_low", "dti", "annual_inc", "purpose"]:
    if c in results.columns:
        show_cols.insert(-3, c)  # place key fields before probability

print("\n" + "=" * 90)
print("PREDICTION RESULTS")
print("=" * 90)
print(results[show_cols].to_string(index=False))
print("=" * 90)
print(f"Avg default probability: {proba.mean():.2%}")
print(f"Predicted defaults:      {pred.sum()} / {len(pred)} ({pred.mean():.2%})")
print(f"Decision threshold:      {threshold:.4f}")
# Out:
# ...
# PREDICTION RESULTS
# ...
#  row_id  loan_amnt       term  int_rate  fico_range_low   dti  annual_inc            purpose  default_probability  predicted_default decision
#       0       3600  36 months     13.99             675  5.91       55000 debt_consolidation             0.413116                  1   REJECT
#       1      24700  36 months     11.99             715 16.06       65000     small_business             0.668264                  1   REJECT
#       2      20000  60 months     10.78             695 10.78       63000   home_improvement             0.466652                  1   REJECT
#       3      22400  60 months     12.88             710 22.98       95000 debt_consolidation             0.488347                  1   REJECT
#       4      16000  60 months     12.88             720 26.40       70000 debt_consolidation             0.512696                  1   REJECT
# ...

# %% [markdown]
#  ## 4. Save Predictions to Disk
#
#  Predictions are saved to `outputs/sample_predictions.csv` for inspection and validation.

# %%
OUTPUTS_DIR = PROJECT_ROOT / "outputs"
OUTPUTS_DIR.mkdir(parents=True, exist_ok=True)

out_path = OUTPUTS_DIR / "sample_predictions.csv"
results[show_cols].to_csv(out_path, index=False)
print(f"\nSaved predictions: {out_path}")
# Out:
# Saved predictions: /Users/avka/Documents/code/Lending-Club-loan/outputs/sample_predictions.csv

# %% [markdown]
#  ## 5. Optional: quick model interpretability (Logistic Regression only)
#
#  If the packaged model is Logistic Regression, we can extract top coefficient drivers.
#  This is **best-effort** — it will gracefully skip if the model is not LR or feature names aren't available.

# %%
def try_print_lr_drivers(pipeline_obj, top_n: int = 12) -> None:
    """Extract and print top LR coefficients if available."""
    if not hasattr(pipeline_obj, "named_steps"):
        print("No named_steps found on pipeline; skipping coefficient extraction.")
        return

    model = pipeline_obj.named_steps.get("model", None)
    preprocess = pipeline_obj.named_steps.get("preprocess", None)

    if model is None or preprocess is None:
        print("Expected steps 'preprocess' and 'model' not found; skipping coefficient extraction.")
        return

    if not hasattr(model, "coef_"):
        print(f"Model type '{type(model).__name__}' has no coef_; skipping.")
        return

    # Get feature names if available
    feature_names = None
    try:
        if hasattr(preprocess, "get_feature_names_out"):
            feature_names = preprocess.get_feature_names_out()
    except Exception:
        feature_names = None

    coefs = model.coef_.ravel()
    if feature_names is None or len(feature_names) != len(coefs):
        print("Could not align feature names with coefficients; skipping.")
        return

    df = pd.DataFrame({"feature": feature_names, "coef": coefs})
    df["abs_coef"] = df["coef"].abs()

    # Positive coef -> higher default risk (given target encoding where 1=default)
    top_pos = df.sort_values("coef", ascending=False).head(top_n)
    top_neg = df.sort_values("coef", ascending=True).head(top_n)

    print("\n" + "=" * 90)
    print("TOP POSITIVE COEFFICIENTS (increase predicted default risk)")
    print("=" * 90)
    print(top_pos[["feature", "coef"]].to_string(index=False))

    print("\n" + "=" * 90)
    print("TOP NEGATIVE COEFFICIENTS (decrease predicted default risk)")
    print("=" * 90)
    print(top_neg[["feature", "coef"]].to_string(index=False))


try_print_lr_drivers(pipeline, top_n=12)
# Out:
# Could not align feature names with coefficients; skipping.

# %% [markdown]
#  ## 6. Optional: tiny wrapper (what you'd use in a service)
#
#  This mirrors a production inference class without making you import external code.

# %%
class CreditRiskPredictor:
    """Thin wrapper around the saved artifact for inference."""

    def __init__(self, pipeline, threshold: float, metadata: dict):
        self.pipeline = pipeline
        self.threshold = float(threshold)
        self.metadata = metadata

    @classmethod
    def from_artifact(cls, path: Path):
        """Load predictor from saved joblib artifact."""
        art = joblib.load(path)
        return cls(
            pipeline=art["pipeline"],
            threshold=float(art["threshold"]),
            metadata=art.get("metadata", {}),
        )

    def predict_proba(self, X: pd.DataFrame) -> np.ndarray:
        """Return default probabilities (0-1) for each application."""
        return self.pipeline.predict_proba(X)[:, 1]

    def predict(self, X: pd.DataFrame) -> np.ndarray:
        """Return binary predictions (0=approve, 1=reject)."""
        return (self.predict_proba(X) >= self.threshold).astype(int)

    def predict_with_details(self, X: pd.DataFrame) -> pd.DataFrame:
        """Return DataFrame with probabilities, predictions, and decisions."""
        p = self.predict_proba(X)
        y = (p >= self.threshold).astype(int)
        return pd.DataFrame(
            {
                "default_probability": p,
                "predicted_default": y,
                "decision": np.where(y == 1, "REJECT", "APPROVE"),
            }
        )

    def get_metadata(self):
        """Return model metadata."""
        return self.metadata

    def get_threshold(self):
        """Return decision threshold used for binary predictions."""
        return self.threshold


predictor = CreditRiskPredictor.from_artifact(artifact_path)

print("\n" + "=" * 90)
print("WRAPPER CLASS DEMO")
print("=" * 90)
print("\nWrapper predictions (first 7 rows):")
print(predictor.predict_with_details(df_sample).head(7).to_string(index=False))

# Get metadata
meta = predictor.get_metadata()
print(f"\nModel metadata:")
print(f"  Created: {meta.get('created_date', 'N/A')}")
test_auc_packaged = meta.get('test_roc_auc')
if isinstance(test_auc_packaged, (int, float)):
    print(f"  Test AUC (packaged): {test_auc_packaged:.4f}")
else:
    print(f"  Test AUC (packaged): {test_auc_packaged}")
if 'selection_test_roc_auc' in meta:
    test_auc_selection = meta['selection_test_roc_auc']
    if isinstance(test_auc_selection, (int, float)):
        print(f"  Test AUC (selection): {test_auc_selection:.4f}")
    else:
        print(f"  Test AUC (selection): {test_auc_selection}")
print(f"  Threshold: {predictor.get_threshold():.4f}")

print("\n✅ Wrapper class demo complete!")
# Out:
# ...
# WRAPPER CLASS DEMO
# ...
#
# Wrapper predictions (first 7 rows):
#  default_probability  predicted_default decision
#             0.413116                  1   REJECT
#             0.668264                  1   REJECT
#             0.466652                  1   REJECT
#             0.488347                  1   REJECT
#             0.512696                  1   REJECT
#             0.428736                  1   REJECT
#
# Model metadata:
#   Created: 2026-01-05 15:03:28
#   Test AUC (packaged): 0.6866
#   Test AUC (selection): 0.6769
#   Threshold: 0.3794
#
# ✅ Wrapper class demo complete!

# %% [markdown]
#  ## 7. Feature Availability Check
#
#  Note: The ColumnAligner transformer in the pipeline ensures robustness.
#  If some features are missing in new data, they are filled with NaN.

# %%
print("\n" + "=" * 90)
print("FEATURE AVAILABILITY IN SAMPLE DATA")
print("=" * 90)

expected_features = [
    # Categorical
    "purpose", "home_ownership", "addr_state", "verification_status",
    # Numeric
    "loan_amnt", "term", "annual_inc", "emp_length", "dti",
    "delinq_2yrs", "inq_last_6mths", "open_acc", "pub_rec",
    "revol_bal", "revol_util", "total_acc",
    "fico_range_low", "fico_range_high", "credit_history_years", "int_rate"
]

available = [f for f in expected_features if f in df_sample.columns]
missing = [f for f in expected_features if f not in df_sample.columns]

print(f"\nAvailable features ({len(available)}):")
print(f"  {', '.join(available)}")

if missing:
    print(f"\nMissing features ({len(missing)}) - will be filled with NaN by ColumnAligner:")
    print(f"  {', '.join(missing)}")
else:
    print(f"\n✓ All expected features available!")

print("\nNote: The ColumnAligner transformer handles missing features gracefully")
print("      by adding them as NaN columns before feature engineering.")
# Out:
# ...
# FEATURE AVAILABILITY IN SAMPLE DATA
# ...
#
# Available features (19):
#   purpose, home_ownership, addr_state, verification_status, loan_amnt, term, annual_inc, emp_length, dti, delinq_2yrs, inq_last_6mths, open_acc, pub_rec, revol_bal, revol_util, total_acc, fico_range_low, fico_range_high, int_rate
#
# Missing features (1) - will be filled with NaN by ColumnAligner:
#   credit_history_years
#
# Note: The ColumnAligner transformer handles missing features gracefully
#       by adding them as NaN columns before feature engineering.

# %% [markdown]
#  ## Summary
#
#  **What we've demonstrated:**
#  1. ✅ Loading saved model artifact from production storage
#  2. ✅ Making predictions on new, unseen loan applications
#  3. ✅ Applying learned decision threshold for binary decisions
#  4. ✅ Production-ready wrapper class for reusable predictions
#  5. ✅ Graceful handling of missing features via ColumnAligner
#
#  **Next Steps:**
#  - Deploy predictor as REST API (Flask/FastAPI)
#  - Monitor prediction distributions for concept drift
#  - Retrain on new data when performance degrades
#  - A/B test different thresholds in production

# %%
print("\n" + "=" * 90)
print("✅ DEPLOYMENT DEMO COMPLETE")
print("=" * 90)
print("\nModel is ready for production deployment.")
print(f"Artifact location: {artifact_path}")
print(f"Sample predictions generated for {len(df_sample)} applications")
print(f"Predictions saved to: {out_path}")
print("=" * 90)
# Out:
# ...
# ✅ DEPLOYMENT DEMO COMPLETE
# ...
#
# Model is ready for production deployment.
# Artifact location: /Users/avka/Documents/code/Lending-Club-loan/models/credit_risk_pipeline_investor.joblib
# Sample predictions generated for 6 applications
# Predictions saved to: /Users/avka/Documents/code/Lending-Club-loan/outputs/sample_predictions.csv
# ...
